# %%
import numpy as np

# %%
np.linspace(-3,3)

# %%
array = np.linspace(-3,3,num=100)
array * 10

# %%
np.random.randint(50,high=101,size=100)
# Out:
# array([ 80,  57,  80,  98,  54,  81,  79,  64,  78,  50,  95,  71,  87,
#         57,  94,  57,  56,  65,  73,  50,  93,  64,  72,  76,  72,  69,
#         79,  95,  89,  65,  76,  99,  73, 100,  75,  59,  56,  90, 100,
#         82, 100,  52,  72,  53,  81,  85,  82,  65,  79, 100,  54,  88,
#         91,  82,  96,  75,  50,  94,  95,  84,  94,  95,  50,  68,  54,
#         65,  58,  99,  93,  54,  62,  82,  97,  98,  74,  68,  84,  98,
#         94,  88,  55,  93,  74,  98,  55,  78,  88,  89,  51,  87,  67,
#         76,  76,  67, 100,  79,  65,  83,  93,  98])

# %%
np.random.randint(50,high=101,size=(5,5))
# Out:
# array([[ 51,  94,  76,  67,  75],
#        [ 61,  99,  65,  66,  90],
#        [ 80,  77, 100,  93,  97],
#        [ 87,  98,  77,  84,  90],
#        [ 94,  55,  71,  54,  57]])

# %%
content = np.random.randint(50,high=101,size=(50,5))

# %%
import pandas as pd
pd.DataFrame(data=content,
             index=range(1,51),
             columns=['國文','英文','數學','地理','歷史'])
# Out:
#     國文   英文   數學   地理   歷史
# 1   80   74   63   94   94
# 2   98  100   97   54   59
# 3   94   86   57  100   54
# 4   70   72   86   99   70
# 5   60   58   95   64   61
# 6   71   90   87   69   54
# 7   83   85   85   86   69
# 8   54   72   95   93   97
# 9   66   69   81   51   56
# 10  89   98   94   95   87
# 11  52   66   89   63   53
# 12  63   51   58   51   98
# 13  93   61   51   60   51
# 14  82   87   77   58   70
# 15  85   56   91   58   59
# 16  64   88  100   64   79
# 17  70   68   87   91   72
# 18  81   79   74   91   67
# 19  99   53   95   86  100
# 20  68   70   94   62   73
# 21  56   69   67   92   76
# 22  63   56   77   62   55
# 23  79   56   57   56   93
# 24  53   88   97   86   98
# 25  89   81   74   74   82
# 26  95   69   87   87   81
# 27  68   96   72   50   55
# 28  93  100   71   56   97
# 29  97   90   82   67   66
# 30  95   55   90   88   81
# 31  86   92  100   85   64
# 32  74   63   80   67   85
# 33  52   62   91   71   58
# 34  91   79   89   74   76
# 35  89   66   65   62   76
# 36  61   56   85  100   68
# 37  91   95   97   59   75
# 38  57   77   97   58   57
# 39  78   70   97   98   99
# 40  71   75  100   63   87
# 41  88   51   77   89   52
# 42  79   90   61   65   92
# 43  97   56   69   95   95
# 44  95   90   80   67   70
# 45  94   65   65   80   97
# 46  80   76   95   67  100
# 47  99   73   81   82   72
# 48  76   75   54   57   53
# 49  63   70   75   87   65
# 50  70   66   78   87   53

# %%
import pandas as pd
df1 = pd.DataFrame(data=content,
             index=range(1,51),
             columns=['國文','英文','數學','地理','歷史'])

# %%
df1['國文'] + df1['英文'] + df1['數學'] + df1['地理'] + df1['歷史']
# Out:
# 1     405
# 2     408
# 3     391
# 4     397
# 5     338
# 6     371
# 7     408
# 8     411
# 9     323
# 10    463
# 11    323
# 12    321
# 13    316
# 14    374
# 15    349
# 16    395
# 17    388
# 18    392
# 19    433
# 20    367
# 21    360
# 22    313
# 23    341
# 24    422
# 25    400
# 26    419
# 27    341
# 28    417
# 29    402
# 30    409
# 31    427
# 32    369
# 33    334
# 34    409
# 35    358
# 36    370
# 37    417
# 38    346
# 39    442
# 40    396
# 41    357
# 42    387
# 43    412
# 44    402
# 45    401
# 46    418
# 47    407
# 48    315
# 49    360
# 50    354
# dtype: int64
